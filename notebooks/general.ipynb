# %% [markdown]
# # Conceptos básicos

# %% [markdown]
# ## Radiación $\alpha, \beta, \gamma$
#
# ### Dos gregos clásicos aos nosos días
#
# No De Rerum Natura de [Lucrecio](https://es.wikipedia.org/wiki/Lucrecio) (século I a.C.), o poeta romano, inspirado por Epicuro e, en última instancia, por Demócrito, expón unha visión da Natureza: _todo o que existe está feito de átomos e baleiro_.
#
# Na nosa visión contemporánea, falamos de partículas fundamentais e baleiro.
#
# Tamén argumenta: _Ningunha cousa volve á nada: todas se disolven e parecen regresar a outros corpos._
#
# Na nosa versión moderna: a enerxía nin se crea nin se destrúe, consérvase. As partículas transfórmanse unhas noutras. É a famosa ecuación de Einstein:
#
# $$
# E = m \, c^2
# $$

# %% [markdown]
# Na actualidade, o noso coñecemento dos compoñentes fundamentais da Natureza está contido no **Modelo Estándar**. _Vaia nome máis desafortunado!_
#
# Clasificar e comprender as interaccións das partículas é unha tarefa inxente que dura desde finais do século XIX, comeza co descubrimento do electrón e chega ata os nosos días, sendo o último gran descubrimento o do bosón de Higgs en 2012.
#
# Non obstante, a imaxe que xorde do Modelo Estándar, aínda que pouco intuitiva, é relativamente simple.
#
# A historia comeza coa táboa periódica.

# %% [markdown]
# ### A táboa periódica
#
# Mendeléiev (1869) clasificou os átomos polas súas propiedades e despois Moseley (1913) ordenounos por Z.
#
# | |
# |:--:|
# | <img src="./imgs/gen_tabla_periodica.png" width = 500 align="center">|
# | Táboa periódica dos elementos [Wikipedia](https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos)
#
#
# A táboa periódica supón unha ordenación dos elementos e permítenos adentrarnos na estrutura atómica (as capas $s, p, d, f$).
#
# Poderemos facer o mesmo coas partículas?

# %% [markdown]
# ## Radiacións ionizantes: α, β, γ
#
# A finais do século XIX e comezos do século XX descubríronse distintos tipos de radiacións, cuxa orixe resultaba descoñecida.
#
# Denomináronse radiacións $\alpha, \beta, \gamma$, e corresponden, respectivamente, ás interaccións forte, feble e electromagnética dos núcleos.
#
# Estas radiacións teñen un rango típico de enerxía do MeV.
#
# A pregunta principal no seu momento era: de onde proviñan esas radiacións? Que as xeraba?

# %% [markdown]
# ### Radiación $\alpha$
#
# A radiación nuclear descubriuna (accidentalmente) Becquerel (1896) e estudouna en detalle Marie Curie.
#
# Henri Becquerel, físico francés, estaba a estudar a fluorescencia de sales de uranio.
# Cría que, ao expoñérense ao sol, estas emitirían raios X.
#
# Un día anubrado, sen sol, gardou as súas placas fotográficas envoltas xunto co uranio.
# Cando as revelou, viu que estaban veladas.
#
# "Les sels d’uranium émettent spontanément des rayonnements capables d’impressionner une plaque photographique à travers un papier opaque." (H. Becquerel) [«As sales de uranio emiten espontaneamente radiacións capaces de impresionar unha placa fotográfica a través dun papel opaco.»]
#
# O uranio emitía unha radiación invisible, _espontánea_, sen necesidade de excitación externa.
# Ese foi o nacemento do concepto de radiactividade natural.

# %% [markdown]
# Posteriormente, [Marie Curie (Skłodowska)](https://en.wikipedia.org/wiki/Marie_Curie) e o seu marido Pierre Curie descubriron dous novos elementos moito máis radiactivos ca o uranio: o polonio e o radio.
#
# Marie acuñou o termo «radioactividade».
#
# Nesta desintegración do uranio emítese unha radiación $\alpha$, isto é, un núcleo de helio (con carga eléctrica $+2e$):
#
# $$
# {}^{238}_{92}\mathrm{U} \rightarrow {}^{234}_{90}\mathrm{Th} + {}^{4}_{2}\mathrm{He}
# $$
#
# Neste caso, a desintegración $\alpha$ corresponde á **segregación** (ou ruptura) do núcleo nunha das súas partes (a partícula alfa).
#
# A radiación $\alpha$ é pouco penetrante por tratarse dunha partícula masiva.
#
# Actualmente o becquerel úsase como unidade para medir as desintegracións/segundo.

# %% [markdown]
# ### Radiación beta
#
# Trátase da emisión dun electrón por parte dun núcleo, por exemplo:
#
# $$
# {}^{14}_{6}\mathrm{C} \;\rightarrow\; {}^{14}_{7}\mathrm{N} \;+\; e \;+\; \bar{\nu}_e
# $$
#
# En 1899 Wilhelm Wien e Ernest Rutherford notan que algunhas partículas emitidas por núcleos radiactivos son moito máis lixeiras ca as alfa e compórtanse como electróns.
#
# En 1913 James Chadwick estuda a dispersión destas partículas e confirma que son electróns emitidos desde o núcleo.
#
# Neste caso, o electrón non está dentro do núcleo, senón que se crea a partir da **desintegración** $\beta$
#
# $$
# n \;\rightarrow\; p \;+\; e \;+\; \bar{\nu}_e
# $$
#
# onde un neutrón se desintegra e dá lugar a un protón, un electrón e un neutrino.

# %% [markdown]
# ### Radiación $\gamma$
#
# Finalmente, algúns núcleos emiten fotóns de alta enerxía, penetrantes, que se denominan raios $\gamma$.
#
# Como é o caso do cobalto:
#
# $$
# {}^{60}_{27}\mathrm{Co} \;\xrightarrow{\beta}\; {}^{60}_{28}\mathrm{Ni}^* + e^- + \bar{\nu}_e \;\xrightarrow{\gamma}\; {}^{60}_{28}\mathrm{Ni} + \gamma
# $$
#
# En 1900 e 1903 Ernest Rutherford e Paul Villard estudan a radiación do torio e do radio, e notan que hai unha compoñente extremadamente penetrante: chámanlle raios gamma. Rutherford identifica que non son partículas cargadas (como $\alpha$ ou $\beta$), senón radiación electromagnética de alta enerxía.
#
# Neste caso trátase da **desexcitación** dun núcleo a un estado de menor enerxía.

# %% [markdown]
# Máis adiante utilizaremos os diagramas de niveis para indicar as desintegracións:
#
# | |
# |:--:|
# | <img src="./imgs/gen_Co60_decay.png" width = 300 align="center">|
# | Diagrama de desintegración do ${}^{60}\mathrm{Co}$ [Wikipedia] |
#
# Podes explorar [aquí](https://www-nds.iaea.org/relnsd/vcharthtml/VChartHTML.html) outros diagramas de niveis

# %% [markdown]
# ### Interaccións electromagnética, feble e forte
#
# Lembremos que a enerxía típica das radiacións nucleares $\alpha, \beta, \gamma$ é do MeV.
#
# A radiación $\gamma$ é _electromagnética_, ten referente clásico.
#
# A desintegración $\beta$ é _débil_, ten un alcance moi pequeno, $10^{-3}$ fm (fm = $10^{-15} \, \mathrm{m}$), e aparece por primeira vez nas reaccións nucleares. O seu tratamento é cuántico.
#
# A desintegración $\alpha$ é unha manifestación da interacción _forte_, a responsable da existencia do núcleo, entre outros fenómenos, e o seu alcance é do fm. De novo, o seu tratamento é cuántico.
#
# En Física Nuclear faremos un tratamento cuántico e -en xeral- non relativista, mentres que en Física de Partículas o tratamento é cuántico e -case sempre- relativista.

# %% [markdown]
# ## Dos núcleos aos quarks
#
# ### Dispersión polo núcleo
#
# En 1909, H. Geiger e E. Marsden estudaban a dispersión de partículas alfa nunha lámina de ouro, e E. Rutherford suxeriu estudar se existían dispersións a ángulos grandes.
#
# | |
# |:--:|
# | <img src="./imgs/gen_alphaexp_diagram.png" width = 240 align="center">|
# | Esquema de dispersión [Geiger, Marsden] |
#
#
# Rutherford: “It was quite the most incredible event that has ever happened to me in my
# life. It was almost as incredible as if you fired a 15-inch shell at a piece of
# tissue paper and it came back and hit you.”

# %% [markdown]
# Rutherford: «Foi a cousa máis incrible que me sucedeu en toda a miña vida. Tan incrible como se disparases un proxectil de 15 polgadas contra unha folla de papel e rebotase!»
#
# Rutherford concluíu, entre outras cousas, que as partículas alfa rebotaban contra o núcleo, a parte central do átomo, que contiña case toda a masa, era diminuta en comparación co átomo e concentraba a súa carga positiva.

# %% [markdown]
# Rutherford describiu a dispersión das partículas alfa a través da
# interacción electromagnética. Supoñendo que o núcleo non tiña retroceso e
# ignorando a interacción cos electróns, a situación é matematicamente a
# mesma que a das solucións de Kepler para as órbitas planetarias: a partícula alfa percorre
# unha hipérbole, cuxo ángulo $\theta$ depende do parámetro de impacto.
#
# | |
# |:--:|
# | <img src="./imgs/gen_alphadisp_parabol.png" width = 240 align="center"> |
# | Dispersión hiperbólica [Rutherford]|
#
# $$
# \frac{d\sigma}{d\Omega} \;=\;
# \left( \frac{1}{4\pi \varepsilon_0} \,
# \frac{Z_1 Z_2 e^2}{4E} \right)^{\!2}
# \frac{1}{\sin^4\!\left(\tfrac{\theta}{2}\right)}
# $$

# %% [markdown]
# ### Dispersión de Mott
#
# Mott estudou a dispersión de electróns de alta enerxía nos núcleos; para iso cómpre ter en conta o espín do electrón e a mecánica cuántica relativista.
#
# $$
# \frac{d\sigma}{d\Omega} \;=\;
# \left( \frac{Z e^2}{16 \pi \varepsilon_0 E} \right)^2
# \frac{1}{\sin^4\!\left(\tfrac{\theta}{2}\right)}
# \;\Big[ 1 - \beta^2 \sin^2\!\left(\tfrac{\theta}{2}\right) \Big]
# $$
#
# E se consideramos o retroceso do núcleo:
#
# $$
# \frac{d\sigma}{d\Omega} \;=\;
# \left( \frac{Z e^2}{16 \pi \varepsilon_0 E} \right)^2
# \frac{1}{\sin^4\!\left(\tfrac{\theta}{2}\right)} \; \frac{E}{E'} \;
# \;\Big[ 1 - \beta^2 \sin^2\!\left(\tfrac{\theta}{2}\right) \Big]
# $$
#
#
# $$
# \quad \text{con} \quad
# E' = \frac{E}{1 + \frac{2 E}{M c^2} \sin^2(\theta/2)},
# %\quad Q^2 = 4 E E' \sin^2(\theta/2)
# $$
#
# onde:
# - $Z$: número atómico do núcleo
# - $E$: enerxía total do electrón incidente
# - $M$: masa do núcleo
# - $\theta$: ángulo de dispersión no laboratorio

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants as const

# --------------------------------------------------
# 1) Dispersión de Rutherford
def sigma_rutherford(Z1, Z2, E, theta):
    """
    Sección eficaz diferencial de Rutherford
    Z1: carga da partícula incidente
    Z2: carga do núcleo
    E: enerxía cinética [J]
    theta: ángulo de dispersión [rad]
    """
    factor = (Z1 * Z2 * const.e**2 / (16 * np.pi * const.epsilon_0 * E))**2
    return factor / (np.sin(theta/2)**4)

# --------------------------------------------------
# 2) Dispersión de Mott con retroceso do núcleo
def sigma_mott(Z, E, M, theta):
    """
    Sección eficaz diferencial de Mott con retroceso
    Z: número atómico do branco
    E: enerxía do electrón incidente [J]
    M: masa do núcleo [kg]
    theta: ángulo de dispersión [rad]
    """
    # enerxía do electrón dispersado considerando o retroceso
    E_prime = E / (1 + (2*E/(M*const.c**2)) * np.sin(theta/2)**2)
    # corrección relativista por espín (aproximada)
    beta = np.sqrt(1 - (const.m_e * const.c**2 / E)**2)
    factor = (Z * const.e**2 / (16 * np.pi * const.epsilon_0 * E))**2
    return factor * (E_prime / E) * (1 - beta**2 * np.sin(theta/2)**2)

# --------------------------------------------------
# 

def plot_cross_sections(E_alpha = 5e6, E_electron = 5e6, M_nucleus = 197):
    theta       = np.linspace(0.01, np.pi, 100)
    E_alpha    *= const.e       # MeV en xulios
    E_electron *= const.e  # MeV en xulios
    M_nucleus  *= const.u         # masa en kg (1 u = 1.660539e-27 kg)

    sigma_R = sigma_rutherford(2, 79, E_alpha, theta)
    sigma_M = sigma_mott(79, E_electron, M_nucleus, theta)

    barn = 1e-24  # 1 barn en m²

    plt.plot(theta/np.pi, sigma_R/barn, label='Rutherford (α)')
    plt.plot(theta/np.pi, sigma_M/barn, label=r'Mott ($\beta$)')
    plt.yscale('log')
    plt.xlabel('Ángulo de dispersión [rad]')
    plt.ylabel('dσ/dΩ [barn/sr]')
    plt.title('Seccións eficaces: Rutherford α e Mott β')
    plt.legend()
    plt.show()

# %%
# Enerxía en eV, masa en uma
plot_cross_sections(E_alpha = 5e6, E_electron = 5e6, M_nucleus = 197)

# %% [markdown]
# ### Descubrimento do protón
#
# Foi Ernest Rutherford quen, en 1917, identificou o protón. Ao bombardear nitróxeno con partículas alfa, observou que na colisión aparecía unha partícula máis lixeira ca a alfa, coa mesma carga positiva pero de masa moito menor.
#
# $$
# {}^{14}\text{N} + \alpha \;\;\longrightarrow\;\; {}^{17}\text{O} + p
# $$
#
# En 1919, Rutherford concluíu que o núcleo do hidróxeno era un constituínte fundamental da materia, presente en todos os núcleos atómicos. Así naceu o concepto de protón como partícula elemental de carga positiva.
#
# Permitiu entender que todos os núcleos podían concibirse como combinacións de protóns (e máis tarde neutróns, tras o seu descubrimento en 1932).
#
# Abriu a porta á idea de transmutacións nucleares: un elemento podía converterse noutro.

# %% [markdown]
# ### Descubrimento do neutrón
#
# O modelo nuclear de Rutherford expoñía que os núcleos estaban compostos unicamente por protóns, pero a masa dos núcleos era maior do que explicaba o número de protóns.
#
# Por exemplo, o núcleo de helio debía ter unha masa de ~4 uma, pero con 2 protóns e 2 electróns (como se especulaba) non cadraba. Faltaba «algo» no núcleo.
#
# En 1930, Walther Bothe e Herbert Becker bombardearon berilio con partículas alfa e detectaron unha radiación moi penetrante, máis ca os raios gamma. Ao principio pensouse que era radiación gamma de alta enerxía.
#
# James Chadwick, no laboratorio Cavendish (Cambridge), estudou con detalle esa radiación. Usou como branco o berilio:
#
# $$
# \alpha + \, {}^9\text{Be} \;\longrightarrow\; \,{} ^{12}\text{C} + \, n
# $$
#
# Esa radiación impactaba en parafina (rica en protóns) e expulsaba protóns da cera. Se fosen fotóns gamma, a enerxía necesaria para expulsar protóns sería enorme. Concluíu que a radiación non eran fotóns, senón partículas neutras de masa comparable á do protón. Chadwick chamou a estas partículas neutróns.
#
# Deste xeito, os núcleos estaban formados por protóns e neutróns (chamados ambos nucleóns).
#
# Explicou por que os núcleos non estoupaban electrostaticamente: os neutróns engadían masa e a forza forte é a que liga os nucleóns no núcleo.

# %% [markdown]
# ### Os catro magníficos
#
# A Natureza está formada por átomos electricamente neutros, constituídos por un núcleo masivo e electróns en capas. O núcleo está formado por protóns (asociados ao número atómico $Z$) e neutróns (que conxuntamente dan o número másico $A$). Os electróns só achegan da orde do 0.1 \% da masa do átomo.
#
# O átomo está baleiro: os núcleos teñen un tamaño da orde de 1-10 fm (fm = $10^{-15}$ m), mentres que o átomo ten $10^{-10}$ m, isto é, entre ambos hai un factor $10^5$!
#
# Así pois, en primeira aproximación, a Natureza está composta por:
#
# $$
# p, \;\; n, \;\ e
# $$
#
# Ademais do neutrino, $\nu$, que aparece na desintegración $\beta$ (e cuxa historia contaremos máis adiante).
#
# Isto é, a materia do Universo está composta por 4 partículas «fundamentais»:
#
#
# $$
# p, \;\; n, \;\; e, \;\; \nu
# $$
#
# Esta visión do mundo construído con $p, n, e$ durou 100 días, ata que se descubriu o positrón!

# %% [markdown]
# ### Dispersión de electróns a alta enerxía
#
# Na década dos 50, Hofstadter realizou unha serie de experimentos de dispersión de electróns de moi alta enerxía (100 MeV) en núcleos co acelerador Mark III en Stanford (California, EUA). E descubriu que os electróns exploraban a estrutura nuclear ao penetraren dentro do núcleo. Acuñou o fermi como unidade de tamaño (fm = $10^{-15}$ m) e estableceu que o núcleo non é unha bóla ríxida.
#
# | |
# |:--:|
# | <img src="./imgs/gen_hofstadter_diagram.png" width = 300 align="center"> |
# | Diagrama da dispersión de Hofstadter|

# %% [markdown]
# Hofstadter verificou que a dispersión de Mott se modifica por un factor, chamado de forma, $F(q^2)$
#
# $$
# \left(\frac{d\sigma}{d\Omega}\right)_{\text{exp}}
# \;=\;
# \left(\frac{d\sigma}{d\Omega}\right)_{\text{Mott}}
# \;\; |F(q^2)|^2
# $$
#
# onde
#
# $$
# q = p - p' =  (E - E', \; {\bf p} - {\bf p}')
# $$
#
# sendo $p, \; p'$ os cuadrimomentos inicial e final do electrón. A $q$ chámaselle cuadrimomento transferido.

# %% [markdown]
# Este factor de forma, como veremos na parte de Nuclear, depende da estrutura do núcleo:
#
# | |
# |:--:|
# | <img src="./imgs/gen_factorforma.png" width = 500 align="center"> |
# | Factores de forma|

# %% [markdown]
# ### Three quark for the Muster Mark!
#
# Na década dos 60, usando electróns de máis alta enerxía, puido explorarse o interior dos propios nucleóns.
#
# Así, as distribucións de forma mostraban patróns que coincidían coa posible existencia de partículas puntuais no interior dos nucleóns. R. Feynman chamounas partóns.
#
# Coñecémolas como quarks. O termo foi introducido por Murray Gell-Mann en 1964, cando propuxo o seu modelo de «quarks» para explicar a estrutura dos hadróns (protóns, neutróns, mesóns), e tomou o nome da novela «Finnegans Wake» (1939) de James Joyce, un libro experimental e case impenetrable, famoso pola súa linguaxe inventiva. Gell-Mann cría que os quarks eran só unha ferramenta matemática para explicar a composición das partículas chamadas hadróns descubertas ata a data.
#
# De forma simultánea, George Zweig, no CERN, tamén propuxo un modelo de constituíntes internos para os hadróns.
# Chamounos “aces” (como os ases dunha baralla). El si cría que eran reais.

# %% [markdown]
# Actualmente dicimos que o protón e o neutrón están formados por dous tipos de quarks.
#
# O quark _up_ ($u$), con carga $2|e|/3$, e o quark _down_ ($d$), con carga $-1|e|/3$.
#
# Deste xeito, cada nucleón está composto por tres quarks, unidos mediante a forza forte, e ten carga enteira:
#
# $$
# n = udd, \;\; p = uud
# $$
#
# | |
# | :--|
# | <img src="./imgs/gen_proton_neutron.jpg" width = 400 align="center"> |
# | Estrutura do protón e do neutrón [Wikipedia]|

# %% [markdown]
# ### Os catro e a súa compañía
#
# As catro partículas fundamentais son:
#
# $$
# u, \;\; d, \;\; e, \;\; \nu
# $$
#
# Pero a Natureza é máis diversa:
#
# * ademais das partículas, existen as _antipartículas_, que teñen as cargas opostas ás das partículas, por exemplo o positrón, $e^+$
#
# * existen outras partículas: outros _leptóns_ (que se comportan como o electrón) e máis _hadróns_ (que están formados por quarks), que son inestables.
#
# Clasificar e ordenar as partículas na táboa de partículas do Modelo Estándar supuxo un reto durante máis de 40 anos.

# %% [markdown]
# ## Conceptos básicos
#
# As interaccións, tanto as nucleares como as das partículas, describímolas mediante ecuacións como a seguinte:
#
# $$
# a + b \to c + d
# $$
#
# onde $a, b$ son as partículas iniciais e $c, d$ son as finais.
#
# Ou nas desintegracións:
#
# $$
# a \to b + c + d
# $$
#
# onde a partícula $a$ se desintegra nas partículas $b, \, c, \, d$
#
# Neste caso aparecen 4 partículas na interacción ou desintegración, pero pode haber outro número.
#
# Por exemplo:
# $$
# \alpha + \, {}^9\text{Be} \;\longrightarrow\; \,{} ^{12}\text{C} + \, n \\
# n \to p \, + e + \bar{\nu}_e
# $$

# %% [markdown]
# ### Sistema de laboratorio e centro de masas
#
# As interaccións referímolas habitualmente a dous sistemas de referencia:
#
# * sistema centro de masas (a suma dos momentos lineais das partículas iniciais é cero)
#
# * sistema de laboratorio (unha das partículas iniciais está en repouso, tipicamente $b$).
#
#
# | |
# |:--|
# | <img src="./imgs/intro_collider_target.png" width = 600 align="center">|
# | Colisión no centro de masas (esquerda) e en branco fixo (dereita) de dúas partículas $a, \, b$.|

# %% [markdown]
# ### Cantidades continuas conservadas
#
# Sabemos polo teorema de E. Noether que por cada simetría continua que presenta un sistema físico se conserva unha cantidade asociada.
#
# Neste caso, para a:
#
# * simetría temporal, conservación da enerxía
#
# * simetría translacional, conservación do momento lineal
#
# * simetría rotacional, conservación do momento angular

# %% [markdown]
# Definimos a enerxía da interacción, $a + b \to c + d$, ou $Q$, como a diferenza de masas iniciais e finais:
#
# $$
# Q = (m_a + m_b - m_c - m_d) \, c^2
# $$
#
# isto é, a enerxía liberada tras a interacción (se $Q>0$) ou a enerxía mínima necesaria para que a interacción poida ter lugar (se $Q <0$).
#
# No caso das desintegracións, $a \to b + c + d$, para que teñan lugar debe cumprirse que:
#
# $$
# Q =  (m_a - m_b - m_c - m_d) \, c^2 > 0
# $$

# %% [markdown]
# No caso do momento lineal, cúmprese que a suma dos momentos lineais antes e despois da interacción é a mesma.
#
# $$
# \sum_i^{iniciais} \mathrm{p}_i = \sum_j^{finais} \mathrm{p}_j
# $$
#
# No caso de que esteamos no centro de masas, a suma dos momentos lineais antes e despois é nula.
#
#
# | | |
# | :--: | :--: |
# | <img src="./imgs/gen_plab.png" width = 300 align="center"> | <img src="./imgs/gen_pcm.png" width = 300 align="center"> |
# | momento no sist. lab.| |momentos no sist. CM [M. Caamaño]|
#
#
# Que valor ten $p_b$? E $p'_b$?

# %% [markdown]
# É moi útil considerar cantidades invariantes Lorentz, que, polo tanto, non dependen do sistema de coordenadas.
#
# En particular, na interacción $a + b \to c+ d$, onde hai catro cuadrimomentos, os iniciais $p_a, p_b$ e os finais $p_c, p_d$, podemos definir uns invariantes Lorentz chamados invariantes de Mandelstam:
#
# $$
# s = (p_a + p_b)^2 = (p_c + p_d)^2 \\
# t = (p_a - p_c)^2 = (p_b - p_d)^2 \\
# u = (p_a - p_d)^2 = (p_b - p_c)^2 \\
# $$
#
# Veremos máis adiante o significado e a utilidade do invariante $s$.

# %% [markdown]
# En particular, no caso da conservación do momento angular, debemos considerar o espín das partículas!
#
# $$
# J_a + J_b + I_{ab} = J_c + J_d + I_{cd}
# $$
#
# | | |
# | :--: | :--: |
# | <img src="./imgs/gen_jlab.png" width = 400 align="center"> | <img src="./imgs/gen_jcm.png" width = 400 align="center"> |

# %% [markdown]
# ### Cantidades discretas
#
# Nas interaccións consérvanse determinadas cantidades aditivas:
#
# * a carga eléctrica
#
# $$
# \sum_i^{iniciais} Q_i = \sum_j^{finais} Q_j
# $$
#
# onde $Q_i$ é a carga de cada partícula.
#
# E veremos que nas interaccións se conservan diversos números cuánticos aditivos:
#
# * número leptónico
#
# * número bariónico
#
# O que nos permite saber se unha interacción se produce ou non na Natureza.

# %% [markdown]
# Unha das propiedades que estudaremos das interaccións é o seu comportamento fronte a dúas transformacións discretas:
#
# * a conxugación de carga: cambiar partículas por antipartículas e viceversa
#
# * a inversión de paridade: cambiar o sistema de referencia ${\bf x} \to -{\bf x}$
#
# Veremos que teñen asociados uns números cuánticos multiplicativos.
#
# En particular, a conxugación de carga e a paridade consérvanse nas interaccións electromagnéticas e fortes, pero non nas febles.
#
# En concreto, non se conserva a paridade na desintegración $\beta$:  $n \to p + e + \bar{\nu}_e$

# %% [markdown]
# Podemos «ilustrar» a conxugación de carga e a inversión de paridade cunha imaxe de Escher:
#
# | | |
# | :--: | :--: |
# | <img src="./imgs/gen_escher_daynight.jpg" width = 400 align="center"> | <img src="./imgs/gen_escher_daynight_p.jpg" width = 400 align="center"> |
# | <img src="./imgs/gen_escher_daynight_p.jpg" width = 400 align="center"> | <img src="./imgs/gen_escher_daynight.jpg" width = 400 align="center"> |

# %% [markdown]
# Fronte á paridade, clasificaremos as cantidades en:
#
# * escalares: $X \to X$
#
# * pseudoescalares: $Y \to -Y$
#
# * vectoriais: $\mathrm{V} \to -\mathrm{V}$
#
# * pseudovectoriais: $\mathrm{A} \to \mathrm{A}$

# %% [markdown]
# ## Observables principais: sección eficaz e vida media
#
# ### Sección eficaz
#
# Boa parte dos experimentos en Nuclear e Partículas son de dispersión: lanzamos partículas sonda contra un branco doutras partículas e estudamos a dispersión das partículas sonda $a$ ou as interaccións $a + b \to c + d$.
#
# Para iso determinamos primeiro o número de interaccións que teñen lugar respecto ao fluxo de partículas sonda e de partículas branco (no caso de experimentos en branco fixo); definimos a sección eficaz como

# %% [markdown]
# en branco fixo), definimos a sección eficaz como
#
# | |
# |:--|
# | <img src="./imgs/gen_xsec.png" width = 400 align="center">|
# | Ilustración da sección eficaz diferencial [M. Caamaño]|
#
#
# $$
# \sigma = \frac{N}{N_b n_a}
# $$
#
# onde $\nu$ é o número de interaccións dun determinado tipo, $a + b \to c + d$, $N_b$ o número de partículas branco, e $n_a = N_a/S$ é o número de partículas sonda $N_a$ que inciden nunha superficie $S$.
#
# A sección eficaz ten dimensións de área, $\mathrm{m}^2$, e a unidade habitual é o barn, $b = 10^{-24}\, \mathrm{cm}^2$

# %% [markdown]
# En xeral, daremos a sección eficaz a partir da taxa de produción das interaccións, $\nu$ (número de interaccións por unidade de tempo), cando incide un fluxo $\phi_a$ ($N_a$ partículas por superficie $S$ e unidade de tempo) sobre $N_b$ partículas branco:
#
# $$
# \sigma = \frac{\nu}{N_b \phi_a}
# $$

# %% [markdown]
# En moitas ocasións consideramos a sección eficaz diferencial respecto á enerxía da partícula sonda:
#
# $$
# \frac{\mathrm{d} \sigma}{\mathrm{d}E} \rightarrow \sigma = \int \frac{\mathrm{d} \sigma}{\mathrm{d}E} \, \mathrm{d}E
# $$
#
# Ou respecto ao ángulo de dispersión
#
# $$
# \frac{\mathrm{d} \sigma}{\mathrm{d}\Omega} \rightarrow \sigma = \int \frac{\mathrm{d} \sigma}{\mathrm{d}\Omega} \, \mathrm{d}\Omega = 2 \pi \int \frac{\mathrm{d}\sigma}{\mathrm{d}\theta} \sin \theta \, \mathrm{d}\theta
# $$
#
# | | |
# |:--: | :--: |
# | <img src="./imgs/gen_xsec_omega.png" width = 400 align="center">|  <img src="./imgs/gen_xsecdif.png" width = 400 align="center">|
# | Ilustración da sección eficaz diferencial [M. Caamaño]| [Wiki] |

# %% [markdown]
# ### Vida media
#
# Outro dos observables principais en Física Nuclear e de Partículas é a vida media dunha desintegración.
#
# Se consideramos a desintegración $a \to b + c +d$ e dispoñemos de $N_a$ partículas $a$ independentes, nunha unidade de tempo agardamos que se produza un número de desintegracións proporcional ao número de partículas iniciais.
#
# $$
# \frac{\mathrm{d}N}{\mathrm{d}t} \propto - N_a
# $$
#
# Isto é, só unha fracción das partículas iniciais se terá desintegrado.

# %% [markdown]
# Á constante de proporcionalidade chamámola vida media, $\tau$:
#
# $$
# \frac{\mathrm{d}N}{\mathrm{d}t} = - \frac{N_a}{\tau} \to N(t) = N_a \, e^{-t/\tau}
# $$
#
# As desintegracións seguen unha lei exponencial.
#
# Por exemplo, para a desintegración do neutrón, $n  \to + p + e + \bar{\nu}_e$, a vida media é $\tau = 878.4$ s.

# %% [markdown]
# ## Bibliografía
#
# M. Caamaño, material para o curso de Física Nuclear e de Partículas.
#
# [[Geiger, Marshen]](https://scholar.google.com/scholar_url?url=https://royalsocietypublishing.org/doi/pdf/10.1098/rspa.1909.0054%3Fdownload%3Dtrue&hl=es&sa=T&oi=ucasa&ct=ufr&ei=ZPi7aPLdOPvoieoPtJ70sAg&scisig=AAZF9b9liGIxuWb0WdsEmpLWlvJk) "On a Diffuse Reflection of the α-Particles". Proceedings of the Royal Society of London A. 82, 557 (1909) 495
#
# [[Rutherford]](https://web.mit.edu/8.13/8.13c/references-fall/rutherford/rutherford-scattering-of-alpha-and-beta-particles.pdf) "LXXIX. The scattering of α and β particles by matter and the
# structure of the atom”. Philosophical Magazine Series 6, 21, 125 (1911) 669
#
# [[Hofstadter]](https://journals.aps.org/pr/abstract/10.1103/PhysRev.92.978) R. Hofstadter et al. “High-Energy Electron Scattering and Nuclear Structure
# Determinations”. Physical Review 92, 4 (1953) 978

# %% [markdown]
# _Para estes apuntamentos utilizouse IA_
