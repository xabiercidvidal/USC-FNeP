# %% [markdown]
# # Introdución á Física de Partículas
#
#
# ## Índice do curso
#
#
# Jose A. Hernando
#
# *Departamento de Física de Partículas. Universidade de Santiago de Compostela*
#
# Setembro 2021

# %% [markdown]
# ## Cuestións prácticas
#
# Profesor: José Ángel Hernando Morata
#
# departamento: Física de Partículas, Instituto Galego de Altas Enerxías, USC
#
# correo electrónico: jose.hernando@usc.es
#
# enderezo: despacho 1, Edificio Monte da Condesa

# %% [markdown]
# ### Apuntamentos do curso
#
# * Os apuntamentos están en [Jupyter Notebooks](https:jupyter.org) (NB).
#
#
#
# * No seguinte repositorio de [GitHub](https://github.com): [xabiercidvidal/USC-FNeP](https://github.com/xabiercidvidal/USC-FNeP)
#
#
#    * O índice está en [indice.ipynb](https://github.com/xabiercidvidal/USC-FNeP/blob/main/notebooks/indice.ipynb).

# %% [markdown]
# ### Obxectivos
#
#
# * Dar unha visión da Física de Partículas e do seu estado
#
#
# * Coñecer as partículas e os conceptos fundamentais sen entrar en detalles nin no formalismo matemático
#
#
# * Unha introdución á Física experimental e a algunhas ferramentas teóricas de cálculo
#
#
#    como detectar partículas, tipos de experimentos, os observables físicos, os diagramas de Feynman
#
#
# * Revisar as partículas fundamentais e as propiedades relevantes do Modelo Estándar de Partículas
#
#    leptóns, hadróns, bosóns Z, W, bosón de Higgs, sabor, violación de paridade, de carga-paridade

# %% [markdown]
# ### Descarga dos apuntamentos
#
# no enderezo: https://github.com/xabiercidvidal/USC-FNeP
#
# descarga:
#
#   * forma sinxela: na lapela **code**, logo **download zip**
#
#   * na consola de Unix (para Mac/Linux) fai un **clone do repositorio**
#
#           git clone https://github.com/xabiercidvidal/USC-FNeP.git

# %% [markdown]
# ### Abrir e editar os NB:
#
#    * vía Anaconda, en Windows e Mac, busca a icona de Jupyter Notebook: [NB](https://jupyter.org/)
#
#    * na consola Unix (Linux/Mac), no directorio onde situaches os apuntamentos, mediante o comando:
#
#           jupyter notebook &

# %% [markdown]
# ## Bibliografía
#
# * [AB] "Elementary Particle Physics", A. Bettini, Cambridge.
#
# * [BM] "Nuclear and Particle Physics, (an introduction)", B. R. Martin, Wiley
#
# * [MS] "Particle Physics", B.R. Martin, G. Shaw, John Wiley & Sons
#
# * [MT] "Modern Particle Physics", Mark Thomson, Cambridge.
#
# * [FH] "Leptons and Quarks", Francis Halzen, Alan D. Martin, Josh Wiley & Sons
#
# * [DG] "Introduction to Elementary Particles", D. Griffiths, Wiley-VCH
#
# * [AL] "Elementary Particle Physcis (an intuitive introduction)", A. Loarkoski, Cambridge

# %% [markdown]
# ## [Introdución](introduccion.ipynb)
#
#  * Introdución á Física de Partículas
#
#  * Introdución ao Modelo Estándar
#
#  * Observables: seccións eficaces e anchuras de desintegración
#
#  * Diagramas de Feynman

# %% [markdown]
# ## [Tema I: detección](./deteccion.ipynb)
#
#  * introdución a aceleradores e colisionadores
#
#  * interacción das partículas coa materia
#
#     * ionización
#     * electróns e fotóns
#     * hadrónica
#
#  * Detectores
#     * tipos de detector: de trazas, calorímetros e Cherenkov
#     * trigger, procesamento e presentación dos observables

# %% [markdown]
# ## [Tema II: leptóns](./leptones.ipynb)
#
#   * Características dos leptóns
#       * Características e familias leptónicas
#       * universalidade leptónica
#
#   * Características das interaccións febles dos leptóns
#       * violación de paridade e helicidade do neutrino.
#       * correntes V-A e quiralidade.
#       * Desintegración do $\pi^\pm$
#
#   * Neutrinos:
#       * oscilacións de neutrinos

# %% [markdown]
# ## [Tema III: quarks e hadróns](./quarks_hadrons.ipynb)

# %% [markdown]
# ## [Tema IV: Modelo Estándar (SM)](./sm.ipynb)

# %% [markdown]
# ## [Apéndice: Fundamentos](./apendice-fundamentos.ipynb)
#
#   * Unidades naturais
#
#   * Amplitudes de desintegración e seccións eficaces:
#
#     * desintegración a dous corpos
#
#     * interacción de dous corpos
#
#   * Invariantes de Mandelstam

# %% [markdown]
# ## [Apéndice: Ecuación de Dirac](./apendice-dirac.ipynb)
#
#  * Ecuación de Dirac
#     * Ecuación de Dirac e matrices $\gamma$s
#  * Solucións da partícula libre.
#     * espinores de fermións e antifermións
#  * Helicidade e quiralidade
#     * espinores autoestados de helicidade
#     * proxectores de quiralidade.

# %% [markdown]
# ## Apéndice: sobre grupos

# %% [markdown]
# ## [Extensión: SM](./extension-sm.ipynb)
